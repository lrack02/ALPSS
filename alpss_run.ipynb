# %% [markdown]
# # Run ALPSS
# ### Note the additional parameters required
# - t_fit_begin
# - t_fit_end
# - carrier_filter_type

# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\Downloads\JHAMAA00001-S2R3C3_2025-12-17_shot01.csv",
    save_data="yes",
    start_time_user='cusum', #cusum, explicit start time, or none
    header_lines=0,
    time_to_skip=2e-6,
    time_to_take=2e-6,
    t_before=50e-9,
    t_after=150e-9,
    start_time_correction=0e-9,
    freq_min=1.5e9,
    freq_max=2.75e9,
    smoothing_window=701,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=128e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=100e-9,
    cusum_offset=30,
    cusum_threshold=100,
    cmap="viridis",
    uncert_mult=10,
    carrier_filter_type='sin_fit_subtract',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=20e-9,
    t_fit_end=200e-9,
    order=6,
    wid=0.1e9,
    lam=1550.016e-9,
    C0=10000,
    density=3000,
    delta_rho=9,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\AIMDL_Laser_Shock Undergrads - Data - Data\PDV_data\mod_output_data"),
    display_plots="yes",
    spall_calculation="yes",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
# 1.40546875e-06
#           Date      Time                                 File Name  \
# 0  Jan 06 2026  03:34 PM  JHAMAA00001-S2R3C3_2025-12-17_shot01.csv
#
#                 Run Time  Velocity at Max Compression  \
# 0 0 days 00:00:01.058390                 2.423757e+11
#
#    Time at Max Compression  Velocity at Max Tension  Time at Max Tension  \
# 0                 0.000001             1.552139e+11             0.000001
#
#    Velocity at Recompression  Time at Recompression  ...  Spall Strength  \
# 0               1.602369e+11               0.000001  ...    1.307426e+09
#
#    Spall Strength Uncertainty   Strain Rate  Strain Rate Uncertainty  \
# 0                3.987146e+07  175585.53129             21946.723198
#
#    Peak Shock Stress  Spect Time Res  Spect Freq Res  Spect Velocity Res  \
# 0       3.635635e+09         0.78125      25000000.0        1.937520e+10
#
#    Signal Start Time  Smoothing Characteristic Time
# 0         1405.46875                   2.128036e-09
#
# [1 rows x 21 columns]
# (<Figure size 3000x1000 with 16 Axes>,
#  {'Date': 'Jan 06 2026',
#   'Time': '03:34 PM',
#   'File Name': 'JHAMAA00001-S2R3C3_2025-12-17_shot01.csv',
#   'Run Time': datetime.timedelta(seconds=1, microseconds=58390),
#   'Velocity at Max Compression': np.float64(242.3756618074204),
#   'Time at Max Compression': np.float64(1.430960937e-06),
#   'Velocity at Max Tension': np.float64(155.2139049095502),
#   'Time at Max Tension': np.float64(1.4557812499999999e-06),
#   'Velocity at Recompression': np.float64(160.2368732447425),
#   'Time at Recompression': np.float64(1.45784375e-06),
#   'Carrier Frequency': np.float64(1880146886.4755058),
#   'Spall Strength': np.float64(1307426353.4680533),
#   'Spall Strength Uncertainty': np.float64(39871461.503438525),
#   'Strain Rate': np.float64(175585.53129017906),
#   'Strain Rate Uncertainty': np.float64(21946.723197586507),
#   'Peak Shock Stress': np.float64(3635634927.111306),
#   'Spect Time Res': np.float64(7.812500000000001e-10),
#   'Spect Freq Res': np.float64(25000000.0),
#   'Spect Velocity Res': np.float64(19.3752),
#   'Signal Start Time': np.float64(1.40546875e-06),
#   'Smoothing Characteristic Time': np.float64(2.1280357142857143e-09)})

# %% [markdown]
# # Running Test File

# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\input_data\example_file.csv",
    save_data="yes",
    start_time_user='cusum', #cusum, explicit start time, or none
    header_lines=1,
    time_to_skip=2.3e-6,
    time_to_take=1.5e-06,
    t_before=5.0e-09,
    t_after=5.0e-08,
    start_time_correction=0e-9,
    freq_min=1.5e9,
    freq_max=4e9,
    smoothing_window=601,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=80e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=2.5e-07,
    cusum_offset=5,
    cusum_threshold=1000,
    cmap="viridis",
    uncert_mult=100,
    carrier_filter_type='sin_fit_subtract',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=20e-9,
    t_fit_end=100e-9,
    order=6,
    wid=0.2e9,
    lam=1550.016e-9,
    C0=6000,
    density=2620,
    delta_rho=9,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\output_data"),
    display_plots="yes",
    spall_calculation="yes",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
#           Date      Time         File Name               Run Time  \
# 0  Aug 21 2025  01:38 PM  example_file.csv 0 days 00:00:00.343409
#
#    Velocity at Max Compression  Time at Max Compression  \
# 0                 8.294407e+11             6.301001e-07
#
#    Velocity at Max Tension  Time at Max Tension  Velocity at Recompression  \
# 0             4.652139e+11         6.476501e-07               5.750115e+11
#
#    Time at Recompression  ...  Spall Strength  Spall Strength Uncertainty  \
# 0           6.557376e-07  ...    2.862822e+09                1.553093e+07
#
#     Strain Rate  Strain Rate Uncertainty  Peak Shock Stress  Spect Time Res  \
# 0  1.729471e+06            408383.975457       6.519404e+09            1.25
#
#    Spect Freq Res  Spect Velocity Res  Signal Start Time  \
# 0    1.562500e+07        1.210950e+10         616.250053
#
#    Smoothing Characteristic Time
# 0                   2.929875e-09
#
# [1 rows x 21 columns]
# (<Figure size 3000x1000 with 16 Axes>,
#  {'Date': 'Aug 21 2025',
#   'Time': '01:38 PM',
#   'File Name': 'example_file.csv',
#   'Run Time': datetime.timedelta(microseconds=343409),
#   'Velocity at Max Compression': np.float64(829.4407228831384),
#   'Time at Max Compression': np.float64(6.301000500044673e-07),
#   'Velocity at Max Tension': np.float64(465.2139433152611),
#   'Time at Max Tension': np.float64(6.476500600052781e-07),
#   'Velocity at Recompression': np.float64(575.0115153558985),
#   'Time at Recompression': np.float64(6.557375600013682e-07),
#   'Carrier Frequency': np.float64(2232111412.128054),
#   'Spall Strength': np.float64(2862822487.403516),
#   'Spall Strength Uncertainty': np.float64(15530930.299746968),
#   'Strain Rate': np.float64(1729470.9022532855),
#   'Strain Rate Uncertainty': np.float64(408383.9754568366),
#   'Peak Shock Stress': np.float64(6519404081.861467),
#   'Spect Time Res': np.float64(1.2500001083347724e-09),
#   'Spect Freq Res': np.float64(15624998.645815466),
#   'Spect Velocity Res': np.float64(12.109498950496153),
#   'Signal Start Time': np.float64(6.162500534090427e-07),
#   'Smoothing Characteristic Time': np.float64(2.9298752539258723e-09)})
