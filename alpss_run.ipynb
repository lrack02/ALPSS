# %% [markdown]
# # Run ALPSS
# ### Note the additional parameters required
# - t_fit_begin
# - t_fit_end
# - carrier_filter_type

# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\input_data\example_file.csv",
    save_data="no",
    start_time_user='cusum', #cusum, explicit start time, or none
    header_lines=0,
    time_to_skip=0e-6,
    time_to_take=5e-6,
    t_before=10e-9,
    t_after=100e-9,
    start_time_correction=0e-9,
    freq_min=1e9,
    freq_max=3e9,
    smoothing_window=601,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=128e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=100e-9,
    cusum_offset=5,
    cusum_threshold=1000,
    cmap="viridis",
    uncert_mult=10,
    carrier_filter_type='sin_fit_subtract',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=50e-9,
    t_fit_end=300e-9,
    order=6,
    wid=0.05e9,
    lam=1550.016e-9,
    C0=6000,
    density=2620,
    delta_rho=9,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\output_data"),
    display_plots="yes",
    spall_calculation="no",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
# (<Figure size 3000x1000 with 16 Axes>,)

# %% [markdown]
# # Running Test File

# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\input_data\example_file.csv",
    save_data="yes",
    start_time_user='none', #cusum, explicit start time, or none
    header_lines=1,
    time_to_skip=2.3e-6,
    time_to_take=1.5e-06,
    t_before=5.0e-09,
    t_after=5.0e-08,
    start_time_correction=0e-9,
    freq_min=1.5e9,
    freq_max=4e9,
    smoothing_window=601,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=80e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=2.5e-07,
    cusum_offset=5,
    cusum_threshold=1000,
    cmap="viridis",
    uncert_mult=100,
    carrier_filter_type='sin_fit_subtract',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=20e-9,
    t_fit_end=300e-9,
    order=6,
    wid=0.05e9,
    lam=1550.016e-9,
    C0=6000,
    density=2620,
    delta_rho=9,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\output_data"),
    display_plots="yes",
    spall_calculation="yes",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
#           Date      Time         File Name               Run Time  \
# 0  Aug 21 2025  01:34 PM  example_file.csv 0 days 00:00:00.345193
#
#    Velocity at Max Compression  Time at Max Compression  \
# 0                 8.294493e+11             6.300876e-07
#
#    Velocity at Max Tension  Time at Max Tension  Velocity at Recompression  \
# 0             4.652256e+11         6.476626e-07               5.749920e+11
#
#    Time at Recompression  ...  Spall Strength  Spall Strength Uncertainty  \
# 0           6.557251e-07  ...    2.862799e+09                1.549538e+07
#
#     Strain Rate  Strain Rate Uncertainty  Peak Shock Stress  Spect Time Res  \
# 0  1.726996e+06            407219.274573       6.519472e+09            1.25
#
#    Spect Freq Res  Spect Velocity Res  Signal Start Time  \
# 0    1.562500e+07        1.210950e+10         616.250053
#
#    Smoothing Characteristic Time
# 0                   2.929875e-09
#
# [1 rows x 21 columns]
# (<Figure size 3000x1000 with 16 Axes>,
#  {'Date': 'Aug 21 2025',
#   'Time': '01:34 PM',
#   'File Name': 'example_file.csv',
#   'Run Time': datetime.timedelta(microseconds=345193),
#   'Velocity at Max Compression': np.float64(829.4493196072725),
#   'Time at Max Compression': np.float64(6.300875500034331e-07),
#   'Velocity at Max Tension': np.float64(465.22557048814394),
#   'Time at Max Tension': np.float64(6.476625600063124e-07),
#   'Velocity at Recompression': np.float64(574.9919736098384),
#   'Time at Recompression': np.float64(6.557250600003339e-07),
#   'Carrier Frequency': np.float64(2232111412.128054),
#   'Spall Strength': np.float64(2862798668.0763507),
#   'Spall Strength Uncertainty': np.float64(15495378.583900668),
#   'Strain Rate': np.float64(1726996.4050255537),
#   'Strain Rate Uncertainty': np.float64(407219.27457310277),
#   'Peak Shock Stress': np.float64(6519471652.113162),
#   'Spect Time Res': np.float64(1.2500001083347724e-09),
#   'Spect Freq Res': np.float64(15624998.645815466),
#   'Spect Velocity Res': np.float64(12.109498950496153),
#   'Signal Start Time': np.float64(6.162500534090427e-07),
#   'Smoothing Characteristic Time': np.float64(2.9298752539258723e-09)})
