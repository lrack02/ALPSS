# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\OneDrive - Johns Hopkins\AIMDL_Laser_Shock Undergrads - Data - Data\PDV_data\input_data\C1--20250619--00001.csv",
    save_data="no",
    start_time_user='cusum', #cusum, explicit start time, or none
    header_lines=0,
    time_to_skip=0e-6,
    time_to_take=5e-6,
    t_before=10e-9,
    t_after=100e-9,
    start_time_correction=0e-9,
    freq_min=1e9,
    freq_max=2.5e9,
    smoothing_window=601,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=128e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=100e-9,
    cusum_offset=5,
    cusum_threshold=1000,
    cmap="viridis",
    uncert_mult=10,
    carrier_filter_type='none',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=50e-9,
    t_fit_end=300e-9,
    order=6,
    wid=0.05e9,
    lam=1550.016e-9,
    C0=6000,
    density=2620,
    delta_rho=9,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\AIMDL_Laser_Shock Undergrads - Automation HELIX - Automation HELIX\Automation_Paper\PDV_DATA\output_data"),
    display_plots="yes",
    spall_calculation="no",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'ALPSS_env (Python 3.12.9)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
