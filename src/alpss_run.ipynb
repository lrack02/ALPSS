# %% [markdown]
# # Run ALPSS
# ### Note the additional parameters required
# - t_fit_begin
# - t_fit_end
# - carrier_filter_type

# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Papers\MPDV\pdv_data\input_data\pdv_calcite--20260313--00017.csv",
    multipoint_probe = None,
    save_data="yes",
    start_time_user='cusum', #cusum, explicit start time, or none
    header_lines=0,
    time_to_skip=0e-6,
    time_to_take=6e-6,
    t_before=10e-9,
    t_after=1000e-9,
    start_time_correction=0e-9,
    freq_min=1.5e9,
    freq_max=3e9,
    smoothing_window=1501,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=128e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=500e-9,
    cusum_offset=5,
    cusum_threshold=1000,
    cmap="viridis",
    uncert_mult=10,
    carrier_filter_type='gaussian_notch',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=300e-9,
    t_fit_end=800e-9,
    order=6,
    wid=0.1e9,
    lam=1550.016e-9,
    C0=10740,    
    density=3987,
    delta_rho=10,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Papers\Mason_Calcite\pdv_data\output_data"),
    display_plots="yes",
    spall_calculation="no",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
# 1.365203125e-06
# C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Papers\Mason_Calcite\pdv_data\output_data\pdv_calcite--20260313--00017
#           Date      Time                         File Name  \
# 0  Mar 17 2026  10:21 AM  pdv_calcite--20260313--00017.csv
#
#                 Run Time  Velocity at Max Compression  \
# 0 0 days 00:00:03.276099                          NaN
#
#    Time at Max Compression  Velocity at Max Tension  Time at Max Tension  \
# 0                      NaN                      NaN                  NaN
#
#    Velocity at Recompression  Time at Recompression  ...  Spall Strength  \
# 0                        NaN                    NaN  ...             NaN
#
#    Spall Strength Uncertainty  Strain Rate  Strain Rate Uncertainty  \
# 0                         NaN          NaN                      NaN
#
#    Peak Shock Stress  Spect Time Res  Spect Freq Res  Spect Velocity Res  \
# ...

# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\PDV_simulations\PDV_simulated_data\waveform.csv",
    multipoint_probe = None,
    save_data="yes",
    start_time_user='cusum', #cusum, explicit start time, or none
    header_lines=0,
    time_to_skip=0.2e-6,
    time_to_take=5e-6,
    t_before=20e-9,
    t_after=90e-9,
    start_time_correction=0e-9,
    freq_min=1.5e9,
    freq_max=3e9,
    smoothing_window=701,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=128e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=500e-9,
    cusum_offset=5,
    cusum_threshold=1000,
    cmap="viridis",
    uncert_mult=10,
    carrier_filter_type='sin_fit_subtract',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=15e-9,
    t_fit_end=45e-9,
    order=6,
    wid=0.4e9,
    lam=1550.016e-9,
    C0=10740,    
    density=3987,
    delta_rho=10,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Papers\MPDV\pdv_data\output_data"),
    display_plots="yes",
    spall_calculation="no",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
# 2.802742187547e-06
# C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Papers\MPDV\pdv_data\output_data\waveform
#           Date      Time     File Name               Run Time  \
# 0  Mar 17 2026  02:50 PM  waveform.csv 0 days 00:00:01.795922
#
#    Velocity at Max Compression  Time at Max Compression  \
# 0                          NaN                      NaN
#
#    Velocity at Max Tension  Time at Max Tension  Velocity at Recompression  \
# 0                      NaN                  NaN                        NaN
#
#    Time at Recompression  ...  Spall Strength  Spall Strength Uncertainty  \
# 0                    NaN  ...             NaN                         NaN
#
#    Strain Rate  Strain Rate Uncertainty  Peak Shock Stress  Spect Time Res  \
# 0          NaN                      NaN                NaN         0.78125
#
#    Spect Freq Res  Spect Velocity Res  Signal Start Time  \
# 0    2.500000e+07             19.3752        2802.742188
#
# ...

# %% [markdown]
# # Running Test File

# %%
# %reset -f
from alpss_main import alpss_main
# %matplotlib inline

# matplotlib.use('agg')

alpss_main(
    filepath=r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\input_data\example_file.csv",
    save_data="yes",
    start_time_user='cusum', #cusum, explicit start time, or none
    header_lines=1,
    time_to_skip=2.3e-6,
    time_to_take=1.5e-06,
    t_before=5.0e-09,
    t_after=100.0e-09,
    start_time_correction=0e-9,
    freq_min=1.5e9,
    freq_max=4e9,
    smoothing_window=601,
    smoothing_wid=3,
    smoothing_amp=1,
    smoothing_sigma=1,
    smoothing_mu=0,
    pb_neighbors=400,
    pb_idx_correction=0,
    rc_neighbors=400,
    rc_idx_correction=0,
    sample_rate=80e9,
    nperseg=600,
    noverlap=500,
    nfft=5120,
    window="hann",
    blur_kernel=(5, 5),
    blur_sigx=0,
    blur_sigy=0,
    carrier_band_time=2.5e-07,
    cusum_offset=5,
    cusum_threshold=1000,
    cmap="viridis",
    uncert_mult=100,
    carrier_filter_type='sin_fit_subtract',  #sin_fit_subtract, gaussian_notch, or none
    t_fit_begin=50e-9,
    t_fit_end=500e-9,
    order=6,
    wid=0.2e9,
    lam=1550.016e-9,
    C0=6000,
    density=2620,
    delta_rho=9,
    delta_C0=23,
    delta_lam=8e-18,
    theta=0,
    delta_theta=5,
    out_files_dir=(r"C:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\tests\output_data"),
    display_plots="yes",
    spall_calculation="yes",
    plot_figsize=(30, 10),
    plot_dpi=100,
)
# Out:
# 2026-01-14 01:01:23,552 - ERROR - Error in the execution of the main program:: operands could not be broadcast together with shapes (1195,) (1,120000)
# 2026-01-14 01:01:23,556 - ERROR - Traceback: Traceback (most recent call last):
#   File "c:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\src\alpss_main.py", line 42, in alpss_main
#     sdf_out = spall_doi_finder(**inputs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\lucas\OneDrive - Johns Hopkins\Ramesh Lab - Research\Code\ALPSS\src\alpss\spall_doi_finder.py", line 205, in spall_doi_finder
#     t_doi_start_spec_idx = np.argmin(np.abs(t - t_doi_start))
#                                             ~~^~~~~~~~~~~~~
# ValueError: operands could not be broadcast together with shapes (1195,) (1,120000)
# [[0.00000000e+00 7.81200000e-12 1.56250000e-11 ... 9.37476562e-07
#   9.37484375e-07 9.37492187e-07]]
